# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv("training-ds.csv")
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo de Red               964 non-null    object
#  1   Estudiante de Tecnología  964 non-null    object
#  2   Nivel de Educación        964 non-null    object
#  3   Vive en Ciudad            964 non-null    object
#  4   Tipo de Instituto         964 non-null    object
#  5   Edad                      964 non-null    object
#  6   Dispositivo               964 non-null    object
#  7   Tipo de Internet          964 non-null    object
#  8   Situación Financiera      964 non-null    object
#  9   Género                    964 non-null    object
#  10  Duración de la Clase      964 non-null    object
#  11  Nivel de Adaptación       964 non-null    object
# dtypes: object(12)
# memory usage: 90.5+ KB
# None

# %%
data.shape
# Out:
# (964, 12)

# %%
def convertir_mes_a_numero(fecha):
    if len(fecha) == 5 and fecha[1] == '-' and fecha[2:].isdigit():
        return fecha  
    
    meses = {
        'Jan': '1', 'Feb': '2', 'Mar': '3', 'Apr': '4',
        'May': '5', 'Jun': '6', 'Jul': '7', 'Aug': '8',
        'Sep': '9', 'Oct': '10', 'Nov': '11', 'Dec': '12'
    }
    if len(fecha) == 6 and fecha[2] == '-' and fecha[:2].isdigit():
        numero_mes = meses.get(fecha[3:])
        if numero_mes:
            return f"{int(fecha[:2])}-{numero_mes.zfill(2)}"
    
    partes = fecha.split('-')
    numero_mes = meses.get(partes[0])
    if numero_mes:
        return f"{numero_mes}-{partes[1]}"
    else:
        return fecha 

data['Edad'] = data['Edad'].apply(convertir_mes_a_numero)
data['Duración de la Clase'] = data['Duración de la Clase'].apply(convertir_mes_a_numero)

# %%
data
# Out:
#     Tipo de Red Estudiante de Tecnología Nivel de Educación Vive en Ciudad  \
# 0            3G                       Si        Universidad             Si
# 1            3G                       No            Escuela             Si
# 2            3G                       Si        Universidad             Si
# 3            3G                       Si            Escuela             Si
# 4            4G                       Si        Universidad             Si
# ..          ...                      ...                ...            ...
# 959          3G                       No        Universidad             Si
# 960          3G                       No            Escuela             Si
# 961          4G                       No        Universidad             Si
# 962          3G                       No        Universidad             Si
# 963          4G                       No            Escuela             Si
#
#     Tipo de Instituto   Edad  Dispositivo Tipo de Internet  \
# 0             Privado  21-25  Computadora             Wifi
# 1             Privado  11-15   Smartphone     Compra Megas
# 2             Privado  21-25   Smartphone     Compra Megas
# 3             Privado  11-15   Smartphone     Compra Megas
# 4             Privado  21-25  Computadora             Wifi
# ..                ...    ...          ...              ...
# 959           Privado  21-25   Smartphone     Compra Megas
# 960           Privado  11-15   Smartphone     Compra Megas
# 961           Público  21-25   Smartphone     Compra Megas
# 962           Privado  21-25   Smartphone     Compra Megas
# 963           Privado   1-05   Smartphone     Compra Megas
#
#     Situación Financiera     Género Duración de la Clase Nivel de Adaptación
# 0                  Media  Masculino                 3-06                Bajo
# 1                  Media   Femenino                 1-03            Moderado
# 2                   Mala  Masculino                 1-03                Bajo
# 3                  Media  Masculino                 1-03            Moderado
# 4                  Buena  Masculino                 1-03                Alto
# ..                   ...        ...                  ...                 ...
# 959                Media  Masculino                 1-03            Moderado
# 960                Media   Femenino                 1-03            Moderado
# 961                Media  Masculino                    0                Bajo
# 962                Media  Masculino                 1-03            Moderado
# 963                Media   Femenino                 1-03            Moderado
#
# [964 rows x 12 columns]

# %%
display(data.dtypes)
# Out:
# Tipo de Red                 object
# Estudiante de Tecnología    object
# Nivel de Educación          object
# Vive en Ciudad              object
# Tipo de Instituto           object
# Edad                        object
# Dispositivo                 object
# Tipo de Internet            object
# Situación Financiera        object
# Género                      object
# Duración de la Clase        object
# Nivel de Adaptación         object
# dtype: object

# %%
def print_unique_values(data_frame, dtype='object'):
    for column in data_frame.columns:
        if data_frame[column].dtype == dtype:
            print(f'{column}: {list(data_frame[column].unique())}')


print_unique_values(data)
# Out:
# Tipo de Red: ['3G', '4G', '2G']
# Estudiante de Tecnología: ['Si', 'No']
# Nivel de Educación: ['Universidad', 'Escuela', 'Colegio']
# Vive en Ciudad: ['Si', 'No']
# Tipo de Instituto: ['Privado', 'Público']
# Edad: ['21-25', '11-15', '16-20', '26-30', '1-05', '6-10']
# Dispositivo: ['Computadora', 'Smartphone', 'Tableta']
# Tipo de Internet: ['Wifi', 'Compra Megas']
# Situación Financiera: ['Media', 'Mala', 'Buena']
# Género: ['Masculino', 'Femenino']
# Duración de la Clase: ['3-06', '1-03', '0']
# Nivel de Adaptación: ['Bajo', 'Moderado', 'Alto']

# %%
data_transform= data
data_transform = pd.get_dummies(data, columns=[ 'Estudiante de Tecnología', "Vive en Ciudad",'Tipo de Instituto','Tipo de Internet','Género'])
#display(data_transform.head(100))

# %%
# Crear el DataFrame
df = pd.DataFrame(data)
# Codificar las variables categóricas a números usando LabelEncoder
df_encoded = df.apply(LabelEncoder().fit_transform)
# Dividir el DataFrame en variables predictoras (X) y la variable objetivo (y)
X = df_encoded.drop('Nivel de Adaptación', axis=1)
y = df_encoded['Nivel de Adaptación']
# Inicializar el clasificador RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
# Entrenar el modelo
rf_classifier.fit(X, y)
# Obtener la importancia de las características
feature_importances = rf_classifier.feature_importances_
# Crear un DataFrame con las importancias de las características
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
# Mostrar las características más importantes
importance_df
# Out:
#                      Feature  Importance
# 10      Duración de la Clase    0.181185
# 8       Situación Financiera    0.132298
# 5                       Edad    0.130287
# 9                     Género    0.098232
# 4          Tipo de Instituto    0.075108
# 2         Nivel de Educación    0.073862
# 0                Tipo de Red    0.071743
# 3             Vive en Ciudad    0.069197
# 7           Tipo de Internet    0.064026
# 1   Estudiante de Tecnología    0.053043
# 6                Dispositivo    0.051019

# %%
correlation_nivel_adaptacion = df_encoded.corr(method='pearson')['Nivel de Adaptación']
# Correlación con método pearson en orden ascendente
display((correlation_nivel_adaptacion[np.argsort(correlation_nivel_adaptacion, axis=0)[::-1]]).head(11))
# Out:
# Nivel de Adaptación         1.000000
# Situación Financiera        0.258934
# Duración de la Clase        0.209937
# Vive en Ciudad              0.104525
# Dispositivo                 0.066690
# Estudiante de Tecnología    0.044715
# Tipo de Red                 0.021874
# Nivel de Educación         -0.015269
# Género                     -0.042976
# Tipo de Internet           -0.069489
# Tipo de Instituto          -0.172572
# Name: Nivel de Adaptación, dtype: float64

# %%
def print_zeros_values(data_frame):
    for column in data_frame.columns:
        print (f'{column}: {sum(data_frame[column] == 0)}')

print_zeros_values(data_transform)
# Out:
# Tipo de Red: 0
# Nivel de Educación: 0
# Edad: 0
# Dispositivo: 0
# Situación Financiera: 0
# Duración de la Clase: 0
# Nivel de Adaptación: 0
# Estudiante de Tecnología_No: 243
# Estudiante de Tecnología_Si: 721
# Vive en Ciudad_No: 756
# Vive en Ciudad_Si: 208
# Tipo de Instituto_Privado: 302
# Tipo de Instituto_Público: 662
# Tipo de Internet_Compra Megas: 413
# Tipo de Internet_Wifi: 551
# Género_Femenino: 532
# Género_Masculino: 432

# %%
data_transform = data_transform.rename(columns={'Nivel de Adaptación':'Nivel de Adaptacion'})
data_transform.insert(loc=len(data_transform.columns)-1, column='Nivel de Adaptacion', value=data_transform.pop('Nivel de Adaptacion'))

# %%
correlation_level_adaption = data_transform.corrwith(data_transform['Nivel de Adaptacion'], method='kendall')
# Ordenar por valor absoluto en orden descendente
correlation_level_adaption = correlation_level_adaption.abs().sort_values(ascending=False)
print(correlation_level_adaption.head(11))
# Out:
# Tipo de Instituto_Privado        0.205034
# Tipo de Instituto_Público        0.205034
# Vive en Ciudad_No                0.136796
# Vive en Ciudad_Si                0.136796
# Estudiante de Tecnología_No      0.064079
# Estudiante de Tecnología_Si      0.064079
# Tipo de Internet_Compra Megas    0.049212
# Tipo de Internet_Wifi            0.049212
# Género_Femenino                  0.024113
# Género_Masculino                 0.024113
# dtype: float64
# C:\Users\miky1\AppData\Local\Temp\ipykernel_18064\2588461948.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_level_adaption = data_transform.corrwith(data_transform['Nivel de Adaptacion'], method='kendall')

# %%
correlation_level_adaption = data.corrwith(data['Nivel de Adaptación'], method='kendall')
# Ordenar por valor absoluto en orden descendente
print(correlation_level_adaption)
# Out:
# Series([], dtype: float64)
# C:\Users\miky1\AppData\Local\Temp\ipykernel_18064\1892343149.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_level_adaption = data.corrwith(data['Nivel de Adaptación'], method='kendall')

# %%
df_chi = pd.DataFrame(data)

# Obtener todas las columnas categóricas (excluyendo la columna 'Nivel de Adaptación')
categorical_columns = df_chi.select_dtypes(include=['object']).columns.tolist()
categorical_columns.remove('Nivel de Adaptación')

# Realizar la prueba de Chi-cuadrado para cada columna categórica
results = {}
for column in categorical_columns:
    contingency_table = pd.crosstab(df_chi['Nivel de Adaptación'], df_chi[column])
    chi2, p, _, _ = chi2_contingency(contingency_table)
    results[column] = {'Chi-cuadrado': chi2, 'Valor p': p}

# Mostrar los resultados
for column, result in results.items():
    print(f"Variable: {column}")
    print(f"Chi-cuadrado: {result['Chi-cuadrado']}")
    print(f"Valor p: {result['Valor p']}")
    print("---------")
# Out:
# Variable: Tipo de Red
# Chi-cuadrado: 22.416899468049962
# Valor p: 0.00016553607337707634
# ---------
# Variable: Estudiante de Tecnología
# Chi-cuadrado: 18.071856218207742
# Valor p: 0.00011905462826913621
# ---------
# Variable: Nivel de Educación
# Chi-cuadrado: 34.12387833220294
# Valor p: 7.028430339688034e-07
# ---------
# Variable: Vive en Ciudad
# Chi-cuadrado: 58.93948394141377
# Valor p: 1.590207066435886e-13
# ---------
# Variable: Tipo de Instituto
# Chi-cuadrado: 86.2495346195265
# Valor p: 1.8670309785740594e-19
# ---------
# Variable: Edad
# Chi-cuadrado: 99.38765927838557
# Valor p: 7.225920028459192e-17
# ---------
# Variable: Dispositivo
# Chi-cuadrado: 43.667029513202095
# Valor p: 7.523116516226196e-09
# ---------
# Variable: Tipo de Internet
# Chi-cuadrado: 14.865597060186293
# Valor p: 0.000591529779493374
# ---------
# Variable: Situación Financiera
# Chi-cuadrado: 169.29098707058372
# Valor p: 1.48468306911087e-35
# ---------
# Variable: Género
# Chi-cuadrado: 11.77281525381296
# Valor p: 0.0027769345850669797
# ---------
# Variable: Duración de la Clase
# Chi-cuadrado: 175.07187246811478
# Valor p: 8.526003556326326e-37
# ---------

# %%
significative_columns = [column for column, result in results.items() if result['Valor p'] < 0.05]

# Utilizar estas columnas significativas para entrenar tu red neuronal
# X serían tus datos con estas columnas seleccionadas y 'Nivel de Adaptación' sería tu variable objetivo
X = df_chi[significative_columns]
y = df_chi['Nivel de Adaptación']

# %%
data2 = data
data2
# Out:
#     Tipo de Red Estudiante de Tecnología Nivel de Educación Vive en Ciudad  \
# 0            3G                       Si        Universidad             Si
# 1            3G                       No            Escuela             Si
# 2            3G                       Si        Universidad             Si
# 3            3G                       Si            Escuela             Si
# 4            4G                       Si        Universidad             Si
# ..          ...                      ...                ...            ...
# 959          3G                       No        Universidad             Si
# 960          3G                       No            Escuela             Si
# 961          4G                       No        Universidad             Si
# 962          3G                       No        Universidad             Si
# 963          4G                       No            Escuela             Si
#
#     Tipo de Instituto   Edad  Dispositivo Tipo de Internet  \
# 0             Privado  21-25  Computadora             Wifi
# 1             Privado  11-15   Smartphone     Compra Megas
# 2             Privado  21-25   Smartphone     Compra Megas
# 3             Privado  11-15   Smartphone     Compra Megas
# 4             Privado  21-25  Computadora             Wifi
# ..                ...    ...          ...              ...
# 959           Privado  21-25   Smartphone     Compra Megas
# 960           Privado  11-15   Smartphone     Compra Megas
# 961           Público  21-25   Smartphone     Compra Megas
# 962           Privado  21-25   Smartphone     Compra Megas
# 963           Privado   1-05   Smartphone     Compra Megas
#
#     Situación Financiera     Género Duración de la Clase Nivel de Adaptación
# 0                  Media  Masculino                 3-06                Bajo
# 1                  Media   Femenino                 1-03            Moderado
# 2                   Mala  Masculino                 1-03                Bajo
# 3                  Media  Masculino                 1-03            Moderado
# 4                  Buena  Masculino                 1-03                Alto
# ..                   ...        ...                  ...                 ...
# 959                Media  Masculino                 1-03            Moderado
# 960                Media   Femenino                 1-03            Moderado
# 961                Media  Masculino                    0                Bajo
# 962                Media  Masculino                 1-03            Moderado
# 963                Media   Femenino                 1-03            Moderado
#
# [964 rows x 12 columns]

# %%
data['Nivel de Adaptación']
# Out:
# 0          Bajo
# 1      Moderado
# 2          Bajo
# 3      Moderado
# 4          Alto
#          ...
# 959    Moderado
# 960    Moderado
# 961        Bajo
# 962    Moderado
# 963    Moderado
# Name: Nivel de Adaptación, Length: 964, dtype: object

# %%
#data = data2

# %%
# Mapear los valores de la columna 'Nivel de Adaptación' a números
mapping = {'Bajo': 0, 'Moderado': 1, 'Alto': 2}
data['Nivel de Adaptación'] = data['Nivel de Adaptación'].map(mapping)

# Verificar el resultado
print(data['Nivel de Adaptación'])
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      2
#       ..
# 959    1
# 960    1
# 961    0
# 962    1
# 963    1
# Name: Nivel de Adaptación, Length: 964, dtype: int64

# %%
data
# Out:
#     Tipo de Red Estudiante de Tecnología Nivel de Educación Vive en Ciudad  \
# 0            3G                       Si        Universidad             Si
# 1            3G                       No            Escuela             Si
# 2            3G                       Si        Universidad             Si
# 3            3G                       Si            Escuela             Si
# 4            4G                       Si        Universidad             Si
# ..          ...                      ...                ...            ...
# 959          3G                       No        Universidad             Si
# 960          3G                       No            Escuela             Si
# 961          4G                       No        Universidad             Si
# 962          3G                       No        Universidad             Si
# 963          4G                       No            Escuela             Si
#
#     Tipo de Instituto   Edad  Dispositivo Tipo de Internet  \
# 0             Privado  21-25  Computadora             Wifi
# 1             Privado  11-15   Smartphone     Compra Megas
# 2             Privado  21-25   Smartphone     Compra Megas
# 3             Privado  11-15   Smartphone     Compra Megas
# 4             Privado  21-25  Computadora             Wifi
# ..                ...    ...          ...              ...
# 959           Privado  21-25   Smartphone     Compra Megas
# 960           Privado  11-15   Smartphone     Compra Megas
# 961           Público  21-25   Smartphone     Compra Megas
# 962           Privado  21-25   Smartphone     Compra Megas
# 963           Privado   1-05   Smartphone     Compra Megas
#
#     Situación Financiera     Género Duración de la Clase  Nivel de Adaptación
# 0                  Media  Masculino                 3-06                    0
# 1                  Media   Femenino                 1-03                    1
# 2                   Mala  Masculino                 1-03                    0
# 3                  Media  Masculino                 1-03                    1
# 4                  Buena  Masculino                 1-03                    2
# ..                   ...        ...                  ...                  ...
# 959                Media  Masculino                 1-03                    1
# 960                Media   Femenino                 1-03                    1
# 961                Media  Masculino                    0                    0
# 962                Media  Masculino                 1-03                    1
# 963                Media   Femenino                 1-03                    1
#
# [964 rows x 12 columns]

# %%
x = data.drop('Nivel de Adaptación' , axis = 1)
y = data['Nivel de Adaptación']

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      2
#       ..
# 959    1
# 960    1
# 961    0
# 962    1
# 963    1
# Name: Nivel de Adaptación, Length: 964, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(pd.get_dummies(x) , y , test_size = 0.2 , random_state = 42)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape = x_train.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100 , activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100 , activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(3 , activation = 'softmax')
])

model.compile(loss = tf.keras.losses.sparse_categorical_crossentropy , optimizer = tf.keras.optimizers.Adam() , metrics = ['accuracy'])

model.fit(x_train , y_train , epochs = 100)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 2ms/step - loss: 1.0466 - accuracy: 0.5629
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6741 - accuracy: 0.7393
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.7977
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4777 - accuracy: 0.8288
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4776 - accuracy: 0.8223
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4179 - accuracy: 0.8482
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.8379
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3852 - accuracy: 0.8573
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8560
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3744 - accuracy: 0.8444
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8470
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8612
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8547
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8833
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8638
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3437 - accuracy: 0.8703
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8573
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8651
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.8807
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3140 - accuracy: 0.8716
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2981 - accuracy: 0.8911
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3219 - accuracy: 0.8560
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.8794
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3259 - accuracy: 0.8534
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.8664
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8547
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3104 - accuracy: 0.8677
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8599
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3024 - accuracy: 0.8807
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3011 - accuracy: 0.8625
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8625
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3216 - accuracy: 0.8703
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.8664
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.8755
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2950 - accuracy: 0.8768
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3093 - accuracy: 0.8846
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2991 - accuracy: 0.8729
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8742
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.8742
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.8625
# Epoch 41/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2927 - accuracy: 0.8768
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2884 - accuracy: 0.8859
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2854 - accuracy: 0.8872
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.8794
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2938 - accuracy: 0.8677
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.8755
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.8638
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3063 - accuracy: 0.8742
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3069 - accuracy: 0.8586
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2928 - accuracy: 0.8820
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8846
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2964 - accuracy: 0.8781
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 0.8820
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8807
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.8690
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.8781
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2928 - accuracy: 0.8781
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.8781
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.8716
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2870 - accuracy: 0.8911
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.8911
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8560
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3064 - accuracy: 0.8690
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8664
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2878 - accuracy: 0.8898
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8703
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2920 - accuracy: 0.8807
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3123 - accuracy: 0.8703
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2922 - accuracy: 0.8690
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2872 - accuracy: 0.8755
# Epoch 71/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.8794
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2989 - accuracy: 0.8664
# Epoch 73/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2995 - accuracy: 0.8638
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8859
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.8599
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2974 - accuracy: 0.8690
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.8651
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2877 - accuracy: 0.8923
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2840 - accuracy: 0.8807
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.8820
# Epoch 81/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3070 - accuracy: 0.8625
# Epoch 82/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.8872
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.8833
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.8807
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.8729
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3000 - accuracy: 0.8586
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.8768
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2811 - accuracy: 0.8664
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.8768
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.8846
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.8833
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8807
# Epoch 93/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2829 - accuracy: 0.8690
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.8794
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2648 - accuracy: 0.8898
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.8898
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2737 - accuracy: 0.8703
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2755 - accuracy: 0.8872
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.8872
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2759 - accuracy: 0.8833

# %%
loss , acc = model.evaluate(x_test , y_test)
acc
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3464 - accuracy: 0.8549
# 0.8549222946166992

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForestClassifier().fit(x_train , y_train).score(x_test , y_test)
# Out:
# 0.844559585492228

# %%
X_encod = df_encoded.drop('Nivel de Adaptación' , axis = 1)
y_encod = df_encoded['Nivel de Adaptación']
x_train_encod , x_test_encod , y_train_encod , y_test_encod = train_test_split(X_encod , y_encod , test_size = 0.2 , random_state = 42)
model_encode = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape = x_train_encod.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100 , activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100 , activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(3 , activation = 'softmax')
])

model_encode.compile(loss = tf.keras.losses.sparse_categorical_crossentropy , optimizer = tf.keras.optimizers.Adam() , metrics = ['accuracy'])

model_encode.fit(x_train_encod , y_train_encod , epochs = 100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 14ms/step - loss: 1.4943 - accuracy: 0.4692 - val_loss: 1.2630 - val_accuracy: 0.4516
# Epoch 2/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1859 - accuracy: 0.6023 - val_loss: 1.1219 - val_accuracy: 0.6000
# Epoch 3/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.0585 - accuracy: 0.6721 - val_loss: 1.0816 - val_accuracy: 0.5871
# Epoch 4/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9490 - accuracy: 0.6721 - val_loss: 1.0551 - val_accuracy: 0.5806
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9148 - accuracy: 0.6851 - val_loss: 1.0159 - val_accuracy: 0.6065
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9016 - accuracy: 0.7175 - val_loss: 0.9860 - val_accuracy: 0.6452
# Epoch 7/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8925 - accuracy: 0.7127 - val_loss: 0.9710 - val_accuracy: 0.6258
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8362 - accuracy: 0.7224 - val_loss: 0.9445 - val_accuracy: 0.6194
# Epoch 9/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8457 - accuracy: 0.7289 - val_loss: 0.9249 - val_accuracy: 0.6839
# Epoch 10/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8785 - accuracy: 0.7240 - val_loss: 0.9046 - val_accuracy: 0.7032
# Epoch 11/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8078 - accuracy: 0.7321 - val_loss: 0.8761 - val_accuracy: 0.7355
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7849 - accuracy: 0.7451 - val_loss: 0.8627 - val_accuracy: 0.6968
# Epoch 13/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7501 - accuracy: 0.7630 - val_loss: 0.8499 - val_accuracy: 0.7290
# Epoch 14/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7410 - accuracy: 0.7549 - val_loss: 0.8385 - val_accuracy: 0.7548
# Epoch 15/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7505 - accuracy: 0.7614 - val_loss: 0.8183 - val_accuracy: 0.7355
# Epoch 16/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7771 - accuracy: 0.7403 - val_loss: 0.8041 - val_accuracy: 0.7548
# Epoch 17/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7496 - accuracy: 0.7760 - val_loss: 0.8102 - val_accuracy: 0.7419
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6786 - accuracy: 0.7695 - val_loss: 0.7887 - val_accuracy: 0.7613
# Epoch 19/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7140 - accuracy: 0.7760 - val_loss: 0.7826 - val_accuracy: 0.7677
# Epoch 20/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6955 - accuracy: 0.7825 - val_loss: 0.7835 - val_accuracy: 0.7871
# Epoch 21/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6904 - accuracy: 0.7857 - val_loss: 0.7696 - val_accuracy: 0.7806
# Epoch 22/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6640 - accuracy: 0.7890 - val_loss: 0.7482 - val_accuracy: 0.7871
# Epoch 23/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6754 - accuracy: 0.7857 - val_loss: 0.7405 - val_accuracy: 0.7806
# Epoch 24/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6477 - accuracy: 0.8019 - val_loss: 0.7303 - val_accuracy: 0.7871
# Epoch 25/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.8052 - val_loss: 0.7337 - val_accuracy: 0.7742
# Epoch 26/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7033 - accuracy: 0.7744 - val_loss: 0.7343 - val_accuracy: 0.7871
# Epoch 27/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.7825 - val_loss: 0.7188 - val_accuracy: 0.7935
# Epoch 28/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6421 - accuracy: 0.8019 - val_loss: 0.7321 - val_accuracy: 0.7871
# Epoch 29/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6523 - accuracy: 0.8036 - val_loss: 0.7383 - val_accuracy: 0.7613
# Epoch 30/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6569 - accuracy: 0.7841 - val_loss: 0.7349 - val_accuracy: 0.7677
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6431 - accuracy: 0.7873 - val_loss: 0.7347 - val_accuracy: 0.7742
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6490 - accuracy: 0.7873 - val_loss: 0.7284 - val_accuracy: 0.7613
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6283 - accuracy: 0.7955 - val_loss: 0.7240 - val_accuracy: 0.7613
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6050 - accuracy: 0.8101 - val_loss: 0.7148 - val_accuracy: 0.7677
# Epoch 35/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6279 - accuracy: 0.8084 - val_loss: 0.7089 - val_accuracy: 0.7742
# Epoch 36/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5781 - accuracy: 0.8198 - val_loss: 0.7182 - val_accuracy: 0.7806
# Epoch 37/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6073 - accuracy: 0.8198 - val_loss: 0.7082 - val_accuracy: 0.7677
# Epoch 38/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6080 - accuracy: 0.8133 - val_loss: 0.7033 - val_accuracy: 0.7742
# Epoch 39/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6107 - accuracy: 0.8149 - val_loss: 0.7101 - val_accuracy: 0.7935
# Epoch 40/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6061 - accuracy: 0.8101 - val_loss: 0.7166 - val_accuracy: 0.7742
# Epoch 41/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5932 - accuracy: 0.8214 - val_loss: 0.7035 - val_accuracy: 0.7742
# Epoch 42/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5680 - accuracy: 0.8247 - val_loss: 0.7053 - val_accuracy: 0.7742
# Epoch 43/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6160 - accuracy: 0.8036 - val_loss: 0.6902 - val_accuracy: 0.7742
# Epoch 44/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5951 - accuracy: 0.8068 - val_loss: 0.6956 - val_accuracy: 0.7806
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5664 - accuracy: 0.8117 - val_loss: 0.6928 - val_accuracy: 0.7871
# Epoch 46/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5997 - accuracy: 0.8166 - val_loss: 0.6768 - val_accuracy: 0.7935
# Epoch 47/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5956 - accuracy: 0.8133 - val_loss: 0.6809 - val_accuracy: 0.7871
# Epoch 48/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5757 - accuracy: 0.8247 - val_loss: 0.6603 - val_accuracy: 0.7935
# Epoch 49/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5371 - accuracy: 0.8442 - val_loss: 0.6798 - val_accuracy: 0.7806
# Epoch 50/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5897 - accuracy: 0.8101 - val_loss: 0.6562 - val_accuracy: 0.7871
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5896 - accuracy: 0.8019 - val_loss: 0.6383 - val_accuracy: 0.8065
# Epoch 52/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6050 - accuracy: 0.8052 - val_loss: 0.6577 - val_accuracy: 0.7935
# Epoch 53/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5403 - accuracy: 0.8377 - val_loss: 0.6451 - val_accuracy: 0.8000
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5416 - accuracy: 0.8377 - val_loss: 0.6544 - val_accuracy: 0.7935
# Epoch 55/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5553 - accuracy: 0.8214 - val_loss: 0.6422 - val_accuracy: 0.7935
# Epoch 56/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5709 - accuracy: 0.8279 - val_loss: 0.6342 - val_accuracy: 0.8000
# Epoch 57/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5301 - accuracy: 0.8263 - val_loss: 0.6395 - val_accuracy: 0.8065
# Epoch 58/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5558 - accuracy: 0.8279 - val_loss: 0.6339 - val_accuracy: 0.8000
# Epoch 59/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5549 - accuracy: 0.8117 - val_loss: 0.6240 - val_accuracy: 0.8065
# Epoch 60/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5397 - accuracy: 0.8198 - val_loss: 0.6423 - val_accuracy: 0.8000
# Epoch 61/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5624 - accuracy: 0.8231 - val_loss: 0.6270 - val_accuracy: 0.7935
# Epoch 62/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5458 - accuracy: 0.8344 - val_loss: 0.6157 - val_accuracy: 0.8258
# Epoch 63/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5362 - accuracy: 0.8344 - val_loss: 0.6069 - val_accuracy: 0.8000
# Epoch 64/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5449 - accuracy: 0.8166 - val_loss: 0.6144 - val_accuracy: 0.8194
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5514 - accuracy: 0.8263 - val_loss: 0.6041 - val_accuracy: 0.8000
# Epoch 66/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5238 - accuracy: 0.8312 - val_loss: 0.6173 - val_accuracy: 0.8194
# Epoch 67/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5602 - accuracy: 0.8117 - val_loss: 0.6036 - val_accuracy: 0.8129
# Epoch 68/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5127 - accuracy: 0.8474 - val_loss: 0.6229 - val_accuracy: 0.7935
# Epoch 69/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5137 - accuracy: 0.8279 - val_loss: 0.6277 - val_accuracy: 0.7935
# Epoch 70/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5360 - accuracy: 0.8279 - val_loss: 0.6072 - val_accuracy: 0.8129
# Epoch 71/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5308 - accuracy: 0.8377 - val_loss: 0.5890 - val_accuracy: 0.8194
# Epoch 72/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5432 - accuracy: 0.8084 - val_loss: 0.5996 - val_accuracy: 0.8194
# Epoch 73/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5278 - accuracy: 0.8474 - val_loss: 0.5978 - val_accuracy: 0.7935
# Epoch 74/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5206 - accuracy: 0.8425 - val_loss: 0.6076 - val_accuracy: 0.7935
# Epoch 75/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.8295 - val_loss: 0.5852 - val_accuracy: 0.8000
# Epoch 76/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5099 - accuracy: 0.8636 - val_loss: 0.6027 - val_accuracy: 0.8000
# Epoch 77/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5154 - accuracy: 0.8425 - val_loss: 0.5910 - val_accuracy: 0.7871
# Epoch 78/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5106 - accuracy: 0.8377 - val_loss: 0.6159 - val_accuracy: 0.8129
# Epoch 79/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4777 - accuracy: 0.8523 - val_loss: 0.6125 - val_accuracy: 0.8129
# Epoch 80/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4858 - accuracy: 0.8669 - val_loss: 0.6042 - val_accuracy: 0.8258
# Epoch 81/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4977 - accuracy: 0.8474 - val_loss: 0.6000 - val_accuracy: 0.8129
# Epoch 82/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4880 - accuracy: 0.8490 - val_loss: 0.6103 - val_accuracy: 0.8129
# Epoch 83/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5007 - accuracy: 0.8328 - val_loss: 0.5934 - val_accuracy: 0.8194
# Epoch 84/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.8328 - val_loss: 0.5973 - val_accuracy: 0.8129
# Epoch 85/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4942 - accuracy: 0.8669 - val_loss: 0.5939 - val_accuracy: 0.8000
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.8187
# Test accuracy: 0.818652868270874

# %%
loss_encod , acc_encod = model_encode.evaluate(x_test_encod , y_test_encod)
acc_encod
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5432 - accuracy: 0.8394
# 0.8393782377243042

# %%
RandomForestClassifier().fit(x_train_encod , y_train_encod).score(x_test_encod , y_test_encod)
# Out:
# 0.844559585492228
